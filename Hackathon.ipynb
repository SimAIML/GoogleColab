# %% [markdown]
# <a href="https://colab.research.google.com/github/SimAIML/GoogleColab/blob/main/Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 870.6 kB/s eta 0:00:00
# ...

# %%
import numpy as np

# %% [markdown]
# ~~This~~ n *is* just **Testing**

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0,
    groq_api_key='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',
    model_name="llama-3.3-70b-versatile"
)

response =llm.invoke("The first person to be land on moon was")

print(response.content)

# %%
pip install -qU langchain_community beautifulsoup4
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.6 MB/s eta 0:00:00

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader("https://jobs.volvogroup.com/job/G%C3%B6teborg-Head-of-AI-&-Machine-Learning-417-15/1154491855/?feedId=361555")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.
# Head of AI & Machine Learning Job Details | Volvo Group
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Press Tab to Move to Skip to Content Link
# Skip to main content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Language
#
#
# Ceština (Ceská republika)
#
#
# Deutsch (Deutschland)
#
#
# English (United States)
#
#
# Español (México)
#
#
# Suomi (Suomen tasavalta)
#
#
# Français (France)
#
#
# Italiano (Italia)
#
#
# 한국어 (대한민국)
#
#
# Norsk bokmål ‎(Norwegian Bokmål)
#
#
# Nederlands (Nederland)
#
#
# Polski (Polska)
#
#
# Português (Brasil)
#
#
# Svenska (Sverige)
#
#
# 简体中文 (中国大陆)
#
#
#
#
#
# Sign In / View Profile
#
#
#
#
# Employee Login
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 A career with us
#
#
# Reasons to join
# Culture
# Career Development
# Diversity & Inclusion
# Health & Wellbeing
# ...

# %%
from langchain_core.prompts import PromptTemplate
prompt_extract= PromptTemplate.from_template(
    """
    ### SCRAPED TEXT FROM WEBSITE
    {page_data}
    ### INSTRUCTION:
    The scraped text is from the career's page of a website.
    Your job is to extract the job posting and return them in JSON format containing following keys : 'role', 'experience', 'skilss' and description.
    Only return the valid JSON.
    ### VALID JSON (NO PREMBLE):
    """
)

chain_extract = prompt_extract | llm
res = chain_extract.invoke(input={"page_data": page_data})
print(res.content)
# Out:
# ```json
# {
#   "role": "Head of AI & Machine Learning",
#   "experience": "Several years of experience in AI/ML leadership, preferably within the automotive, transportation, or software/technology industries",
#   "skills": [
#     "Proven experience in guiding AI and ML teams",
#     "Building an end-to-end machine learning stack",
#     "Strong technical background in machine learning, deep learning, and AI",
#     "Experience in managing complex AI/ML projects",
#     "Strong communication skills",
#     "Cloud platforms (e.g., AWS, Azure)",
#     "AI/ML frameworks (e.g., TensorFlow, PyTorch)"
#   ],
#   "description": "Volvo Autonomous Solutions is seeking a highly skilled and visionary Head of AI and Machine Learning to lead and drive the development of our AI and ML capabilities across the organization. This is a unique opportunity to shape the future of autonomous technology with a direct impact on Volvo’s innovation and success."
# }
# ```

# %%
from langchain_core.output_parsers import JsonOutputParser
json_parser =JsonOutputParser()
json_res = json_parser.parse(res.content)
print(json_res)
# Out:
# {'role': 'Head of AI & Machine Learning', 'experience': 'Several years of experience in AI/ML leadership, preferably within the automotive, transportation, or software/technology industries', 'skills': ['Proven experience in guiding AI and ML teams', 'Building an end-to-end machine learning stack', 'Strong technical background in machine learning, deep learning, and AI', 'Experience in managing complex AI/ML projects', 'Strong communication skills', 'Cloud platforms (e.g., AWS, Azure)', 'AI/ML frameworks (e.g., TensorFlow, PyTorch)'], 'description': 'Volvo Autonomous Solutions is seeking a highly skilled and visionary Head of AI and Machine Learning to lead and drive the development of our AI and ML capabilities across the organization. This is a unique opportunity to shape the future of autonomous technology with a direct impact on Volvo’s innovation and success.'}

# %%
type(json_res)
# Out:
# dict

# %%
import pandas as pd
df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 582.5 kB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 35.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 58.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 33.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 17.3 MB/s eta 0:00:00
# ...

# %%
import chromadb
import uuid
client = chromadb.PersistentClient(path="vectorstore")
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
  for _,row in df.iterrows():
    collection.add(documents=row["Techstack"], metadatas={"links": row["Links"]}, ids=[str(uuid.uuid4())])
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:07<00:00, 11.4MiB/s]

# %%
job = json_res
job['skills']
# Out:
# ['Proven experience in guiding AI and ML teams',
#  'Building an end-to-end machine learning stack',
#  'Strong technical background in machine learning, deep learning, and AI',
#  'Experience in managing complex AI/ML projects',
#  'Strong communication skills',
#  'Cloud platforms (e.g., AWS, Azure)',
#  'AI/ML frameworks (e.g., TensorFlow, PyTorch)']

# %%
links= collection.query(query_texts=job["skills"], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/devops-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/full-stack-js-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/ios-ar-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/magento-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/android-portfolio'}],
#  [{'links': 'https://example.com/xamarin-portfolio'},
#   {'links': 'https://example.com/devops-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/ios-ar-portfolio'}]]

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}

        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools.
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability,
        process optimization, cost reduction, and heightened overall efficiency.
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ.
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):

        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert AI & Machine Learning Solutions for Volvo Autonomous Solutions
#
# Dear Hiring Manager,
#
# I came across the job posting for the Head of AI & Machine Learning at Volvo Autonomous Solutions, and I was impressed by the company's vision to shape the future of autonomous technology. As a business development executive at AtliQ, an AI & Software Consulting company, I believe our expertise can support your organization in achieving its goals.
#
# At AtliQ, we have a proven track record of empowering enterprises with tailored AI and ML solutions, fostering scalability, process optimization, cost reduction, and heightened overall efficiency. Our team of experts has guided numerous AI and ML projects, built end-to-end machine learning stacks, and demonstrated strong technical backgrounds in machine learning, deep learning, and AI.
#
# ...

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
